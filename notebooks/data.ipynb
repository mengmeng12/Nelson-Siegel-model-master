# %%
import numpy as np
import pandas as pd
# %pylab inline
import matplotlib.pyplot as plt
from tqdm import tqdm_notebook as tqdm
# Out:
# /Users/mm/anaconda3/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# Populating the interactive namespace from numpy and matplotlib

# %%
cd /Users/mm/Desktop/thesis
# Out:
# /Users/mm/Desktop/thesis

# %%
ls data/
# Out:
# CPI_data.xlsx                     macroscopic_prosperity_index.xls
# FRB_H15.csv                       national_debt.xlsx

# %%
cpi_table = pd.read_excel('data/CPI_data.xlsx')
FRB_H15_table = pd.read_table('data/FRB_H15.csv',sep=',')
macro_pros_ind_table = pd.read_excel('data/macroscopic_prosperity_index.xls')
national_debt_table =pd.read_excel('data/national_debt.xlsx')

# %%
display(cpi_table.head())
display(FRB_H15_table.head())
display(macro_pros_ind_table.head())
display(national_debt_table.head())
# Out:
#   日期\指标\n\r  CPI:当月同比\n\r%  CPI:累计同比\n\r%  CPI:环比\n\r%  CPI\n\r上年=100
# 0   2019-02            1.5            1.6          1.0            NaN
# 1   2019-01            1.7            1.7          0.5            NaN
# 2   2018-12            1.9            2.1          0.0          102.1
# 3   2018-11            2.2            2.1         -0.3            NaN
# 4   2018-10            2.5            2.1          0.2            NaN
#     Series Description  \
# 0                Unit:
# 1          Multiplier:
# 2            Currency:
# 3  Unique Identifier:
# 4          Time Period
#
#   Market yield on U.S. Treasury securities at 1-month   constant maturity, quoted on investment basis  \
# 0                                  Percent:_Per_Year
# 1                                                  1
# 2                                                NaN
# 3                             H15/H15/RIFLGFCM01_N.B
# 4                                     RIFLGFCM01_N.B
#
# ...
